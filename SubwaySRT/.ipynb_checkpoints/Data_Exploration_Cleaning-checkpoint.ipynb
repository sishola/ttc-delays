# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


from time import strftime

# %matplotlib inline

plt.rcParams.update({'font.size': 16})
plt.rcParams['axes.axisbelow'] = True
plt.rcParams.update({'figure.autolayout': True})

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Needed Functions

# %%
def sheetsTTC(xlsx_file):
    
    """ 
    Reads in an Excel file and concatenates each sheet into 
    a returned pandas DataFrame.    
    
    Note:
        - Requires: pandas
        - Requires: Each worksheet must have exact matching
                    n columns, column order, column labels
                    and column dtypes.
    """
    
    xls = pd.ExcelFile(xlsx_file)
    
    out_df = pd.DataFrame()
    
    for sheet in xls.sheet_names:
        
        df = pd.read_excel(xls, sheet_name = sheet)
        
        df = df[[
            #'Report Date', 'Route', 'Time', 'Day', 'Location', 'Incident', 'Min Delay', 'Min Gap', 'Direction', 'Vehicle'
            'Date', 'Time', 'Day', 'Station', 'Code', 'Min Delay', 'Min Gap', 'Bound', 'Line', 'Vehicle'
        ]]
        
        out_df = pd.concat([out_df, df])
        
    return out_df

def excelDate(excel_time):
    
    """
    Converts excel datetime float format to pandas datetime
    
    """
    
    return pd.to_datetime('1900-01-01') + pd.to_timedelta(excel_time, 'D')

# %% [markdown]
# ###Import Subway Files, Merge files

# %%
subway = pd.read_csv('./Resources/CleanedData/ttc_subway_srt.csv')
weather = pd.read_csv('./Resources/CleanedData/weather.csv')
holidays = pd.read_csv('./Resources/CleanedData/holidays.csv')
locations = pd.read_csv('./Resources/CleanedData/subway_location.csv')

# %%
#subway.sample(10)

# %%
subway['Date'] = pd.to_datetime(subway['Date'])
weather['Date/Time'] = pd.to_datetime(weather['Date/Time'])
holidays['date'] = pd.to_datetime(holidays['date'])

weather = weather.rename(columns={
    'Date/Time': 'Date', 
    'Mean Temp (°C)': 'Mean Temp', 
    'Total Precip (mm)': 'Precipitation'
})

holidays = holidays.rename(columns={
    'date': 'Date'
})

subway['Month'] = subway['Date'].dt.month
subway['nDay'] = subway['Date'].dt.day

weather = weather.drop(columns=['Year', 'Month', 'Day'])

subway = pd.merge(subway, weather, on='Date', how='left')
subway = pd.merge(subway, holidays, on='Date', how='left')

subway['holiday'] = subway['holiday'].fillna('None')

subway['Line'] = subway['Line'].replace({
    'B/D': 'BD', 
    'YU/ BD': 'YU/BD', 
    'YU / BD': 'YU/BD', 
    'BD LINE': 'BD', 
    'BD/YU': 'YU/BD', 
    'BD/YUS': 'YU/BD', 
    'YUS': 'YU', 
    'YU-BD': 'YU/BD', 
    'YU & BD': 'YU/BD', 
    'YU - BD LINE': 'YU/BD', 
    'YU BD': 'YU/BD',
    'YU LINE': 'YU',
    'BLOOR DANFORTH': 'BD',
    'YONGE UNIVERSITY SERVI': 'YU',
    'SHEPPARD': 'SHP',
    '25 DON MILLS': 'SHP',
    'YUBD': 'YU/BD',
    'YU - BD': 'YU/BD',
    '66': 'YU/BD'
})

subway['Precipitation'] = subway['Total Rain (mm)'] + (subway['Total Snow (cm)']*10)

# %%
subway.to_csv('./Resources/CleanedData/subway_master.csv')

# %%
subway.sample(5)
# Out:
#         Unnamed: 0       Date   Time       Day                Station   Code  \
# 87004        87004 2018-04-02  12:02  Saturday       LAWRENCE STATION  MUPAA
# 8642          8642 2014-05-31  16:20  Thursday      OSSINGTON STATION   MUIR
# 101629      101629 2018-12-09  00:28    Friday          UNION STATION  MUNCA
# 72914        72914 2017-07-15  08:29  Thursday  ST GEORGE YUS STATION    MUI
# 76842        76842 2017-10-01  18:23    Friday       WOODBINE STATION   MUSC
#
#         Min Delay  Min Gap Bound Line  ...  nDay  Max Temp (°C) Min Temp (°C)  \
# 87004           3        7     S   YU  ...     2            6.8          -3.3
# 8642            5        8     W   BD  ...    31           22.5          11.7
# 101629          0        0   NaN   YU  ...     9            1.0          -5.5
# 72914           4        6     S   YU  ...    15           27.6          17.8
# 76842           0        0     W   BD  ...     1           17.7           4.1
#
#         Mean Temp  Total Rain (mm)  Total Snow (cm)  Precipitation  \
# 87004         1.8              0.0              0.0            0.0
# 8642         17.1              0.0              0.0            0.0
# 101629       -2.3              0.0              0.0            0.0
# 72914        22.7              0.0              0.0            0.0
# 76842        10.9              0.0              0.0            0.0
#
#         Snow on Grnd (cm)  Spd of Max Gust (km/h)  holiday
# 87004                 0.0                      34     None
# 8642                  0.0                      34     None
# 101629                0.4                      42     None
# 72914                 0.0                      34     None
# 76842                 0.0                      31     None
#
# [5 rows x 24 columns]

# %%
weather.sample(5)
# Out:
#            Date  Max Temp (°C)  Min Temp (°C)  Mean Temp  Total Rain (mm)  \
# 1338 2017-08-31           19.6           11.0       15.3              1.1
# 753  2016-01-24           -0.1           -9.9       -5.0              0.0
# 653  2015-10-16           12.8            2.7        7.7              0.9
# 77   2014-03-19            5.7           -0.4        2.7              2.2
# 63   2014-03-05           -5.1          -14.0       -9.6              0.0
#
#       Total Snow (cm)  Precipitation  Snow on Grnd (cm)  \
# 1338              0.0            1.5                0.0
# 753               0.0            0.0                0.0
# 653               0.0            1.1                0.0
# 77                0.0            4.6                6.0
# 63                0.0            0.0               19.2
#
#       Spd of Max Gust (km/h)
# 1338                      46
# 753                       33
# 653                       54
# 77                        48
# 63                        31

# %%
holidays.sample(5)
# Out:
#          Date         holiday
# 74 2017-05-22    Victoria Day
# 60 2016-03-25     Good Friday
# 65 2016-10-10    Thanksgiving
# 38 2014-12-25       Christmas
# 27 2013-12-31  Additional Day

# %%
locations.sample(5)
# Out:
#        Unnamed: 0  Unnamed: 0.1        Date   Time       Day  \
# 29845       29845         29845  2015-06-10  19:27    Monday
# 51790       51790         51790  2016-06-28  18:49    Sunday
# 3454         3454          3454  2014-02-27  20:24   Tuesday
# 48981       48981         48981  2016-05-09  22:45  Saturday
# 74214       74214         74207  2017-08-10  19:30   Tuesday
#
#                      Station   Code  Min Delay  Min Gap Bound Line  Vehicle  \
# 29845     KENNEDY BD STATION   TUSC          0        0     E   BD     5304
# 51790     KENNEDY BD STATION  TUMVS          0        0     E   BD     5309
# 3454     KENNEDY SRT STATION   ERPR          7       14     N  SRT     3001
# 48981  YONGE UNIVERSITY LINE   MUGD          0        0   NaN   YU        0
# 74214  BLOOR DANFORTH SUBWAY   MUGD          0        0   NaN   BD        0
#
#        Year                   Description  subway_latitude  subway_longitude
# 29845  2015         Operator Overspeeding              NaN               NaN
# 51790  2016      Operator Violated Signal              NaN               NaN
# 3454   2014             Propulsion System              NaN               NaN
# 48981  2016  Miscellaneous General Delays              NaN               NaN
# 74214  2017  Miscellaneous General Delays              NaN               NaN

# %%
subway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109326 entries, 0 to 109325
# Data columns (total 24 columns):
# Unnamed: 0                109326 non-null int64
# Date                      109326 non-null datetime64[ns]
# Time                      109326 non-null object
# Day                       109326 non-null object
# Station                   109326 non-null object
# Code                      109203 non-null object
# Min Delay                 109326 non-null int64
# Min Gap                   109326 non-null int64
# Bound                     85638 non-null object
# Line                      108889 non-null object
# Vehicle                   109326 non-null int64
# Year                      109326 non-null int64
# Description               106780 non-null object
# Month                     109326 non-null int64
# nDay                      109326 non-null int64
# Max Temp (°C)             109326 non-null float64
# Min Temp (°C)             109326 non-null float64
# Mean Temp                 109326 non-null float64
# Total Rain (mm)           109326 non-null float64
# Total Snow (cm)           109326 non-null float64
# Precipitation             109326 non-null float64
# Snow on Grnd (cm)         109326 non-null float64
# Spd of Max Gust (km/h)    109326 non-null int64
# holiday                   109326 non-null object
# dtypes: datetime64[ns](1), float64(7), int64(8), object(8)
# memory usage: 20.9+ MB

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2191 entries, 0 to 2190
# Data columns (total 9 columns):
# Date                      2191 non-null datetime64[ns]
# Max Temp (°C)             2007 non-null float64
# Min Temp (°C)             2007 non-null float64
# Mean Temp                 2007 non-null float64
# Total Rain (mm)           2191 non-null float64
# Total Snow (cm)           2191 non-null float64
# Precipitation             2191 non-null float64
# Snow on Grnd (cm)         2191 non-null float64
# Spd of Max Gust (km/h)    2191 non-null int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 154.1 KB

# %%
holidays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 2 columns):
# Date       123 non-null datetime64[ns]
# holiday    123 non-null object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 2.0+ KB

# %% [markdown]
# <center><h2>Subway Delay Descriptives</h2></center>

# %%
groupedbyday = subway.groupby(['Date', 'Day']).agg({'Min Delay': 'sum'}).reset_index()

totaldays = len(groupedbyday)
totalmin = groupedbyday['Min Delay'].sum()
meanminperday = round(groupedbyday['Min Delay'].mean(), 2)
medianperday = round(groupedbyday['Min Delay'].median(), 2)
daysdelay = round((groupedbyday['Min Delay'].sum()/60)/24, 2)
percdelay = round(daysdelay / totaldays, 2)
sigmaday = round(groupedbyday['Min Delay'].std(), 2)
delayvariance = round(sigmaday ** 2, 2)

delaystats_dict = {
    'Total Days': totaldays,
    'Total Minutes': totalmin,
    'Days Delayed': daysdelay,
    'Mean Min. per Day': meanminperday,
    'Median Min. per Day': medianperday,
    '% of Days Delayed': percdelay,
    'Daily Sigma': sigmaday,
    'Delay Variance': delayvariance
}

delaystats = pd.DataFrame(delaystats_dict, index=['Stats'])

delaystats = delaystats.style.format({
    '% of Days Delayed': '{:.2%}'.format
})

delaystats
# Out:
# <style  type="text/css" >
# </style><table id="T_691c2d40_a69e_11e9_af95_105bad085232" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Days</th>        <th class="col_heading level0 col1" >Total Minutes</th>        <th class="col_heading level0 col2" >Days Delayed</th>        <th class="col_heading level0 col3" >Mean Min. per Day</th>        <th class="col_heading level0 col4" >Median Min. per Day</th>        <th class="col_heading level0 col5" >% of Days Delayed</th>        <th class="col_heading level0 col6" >Daily Sigma</th>        <th class="col_heading level0 col7" >Delay Variance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_691c2d40_a69e_11e9_af95_105bad085232level0_row0" class="row_heading level0 row0" >Stats</th>
#                         <td id="T_691c2d40_a69e_11e9_af95_105bad085232row0_col0" class="data row0 col0" >1946</td>
#                         <td id="T_691c2d40_a69e_11e9_af95_105bad085232row0_col1" class="data row0 col1" >216403</td>
#                         <td id="T_691c2d40_a69e_11e9_af95_105bad085232row0_col2" class="data row0 col2" >150.28</td>
#                         <td id="T_691c2d40_a69e_11e9_af95_105bad085232row0_col3" class="data row0 col3" >111.2</td>
#                         <td id="T_691c2d40_a69e_11e9_af95_105bad085232row0_col4" class="data row0 col4" >97</td>
#                         <td id="T_691c2d40_a69e_11e9_af95_105bad085232row0_col5" class="data row0 col5" >8.00%</td>
#                         <td id="T_691c2d40_a69e_11e9_af95_105bad085232row0_col6" class="data row0 col6" >74.96</td>
#                         <td id="T_691c2d40_a69e_11e9_af95_105bad085232row0_col7" class="data row0 col7" >5619</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <center><h2>Latitude and Longitude Mapping of Delay Events - Subway</center></h2>

# %%
geo = locations.groupby('Station').agg({
    'subway_latitude': 'mean', 
    'subway_longitude': 'mean',
    'Code': 'count'
})

geo = geo.rename(columns={'Min Delay': 'Min Mean'})

geo = geo[geo['subway_latitude'] > 0].reset_index()

# %%
fig, ax = plt.subplots(1, figsize = [12.5, 7])

ax.scatter(
    geo['subway_longitude'], 
    geo['subway_latitude'], 
    c = geo['Code'], 
    s = geo['Code']/2
)

ax.set_ylabel('Latitude')
ax.set_xlabel('Longitude')
ax.set_title('Subway Locations - Mean minutes of delay 2014 - 2019')

plt.grid(which = 'major', color = '#666666', linestyle = '-')
plt.minorticks_on()
plt.grid(which = 'minor', color = '#666666', linestyle = '-', alpha = 0.2)

plt.tight_layout()

plt.savefig('./Output/Subway Locations - Mean minutes of delay 2014 - 2019')
plt.show()

# %%
station_events = geo[['Station', 'Code']].sort_values('Code', ascending = False)
station_events.head(25)
# Out:
#                   Station  Code
# 31        KIPLING STATION  4900
# 22          FINCH STATION  3562
# 62         WARDEN STATION  2896
# 64         WILSON STATION  2655
# 19       EGLINTON STATION  2591
# 26      ISLINGTON STATION  2582
# 28          KEELE STATION  2580
# 61  VICTORIA PARK STATION  2566
# 4           BLOOR STATION  2404
# 56  ST CLAIR WEST STATION  1957
# 10        COXWELL STATION  1950
# 27           JANE STATION  1915
# 11     DAVISVILLE STATION  1725
# 34       LAWRENCE STATION  1599
# 67     YORK MILLS STATION  1486
# 24      GREENWOOD STATION  1440
# 60          UNION STATION  1365
# 20  EGLINTON WEST STATION  1357
# 41       OLD MILL STATION  1311
# 50       SHEPPARD STATION  1304
# 17    DUNDAS WEST STATION  1263
# 55       ST CLAIR STATION  1221
# 16         DUNDAS STATION  1190
# 18         DUPONT STATION  1163
# 8        CHRISTIE STATION  1157

# %% [markdown]
# <center><h2>Weather and the Subway</center></h2>

# %%
fig, ax = plt.subplots(1, figsize = [12.5, 7])

ax.scatter(
    subway['Mean Temp'], 
    subway['Min Delay'], 
    color = '#680000'
)

ax.set_ylabel('Minutes Delayed per Event')
ax.set_xlabel('Mean Temperature recorded for day of each event')
ax.set_title('Temperature vs Minutes Delayed - Subway 2014 - 2019')

plt.grid(which = 'major', color = '#666666', linestyle = '-')
plt.minorticks_on()
plt.grid(which = 'minor', color = '#666666', linestyle = '-', alpha = 0.2)

plt.tight_layout()
plt.savefig('./Output/Temperature vs Minutes Delayed - Subway 2014 - 2019')

plt.show()

# %%
fig, ax = plt.subplots(1, figsize = [12.5, 7])

ax.scatter(
    subway['Precipitation'], 
    subway['Min Delay'], 
    color = '#680000'
)

ax.set_ylabel('Minutes Delayed per Event')
ax.set_xlabel('Precipitation in mm (Rain + Snow)')
ax.set_title('Precipitation vs Minutes Delayed - Subway 2014 - 2019')

plt.grid(which = 'major', color = '#666666', linestyle = '-')
plt.minorticks_on()
plt.grid(which = 'minor', color = '#666666', linestyle = '-', alpha = 0.2)

plt.tight_layout()
plt.savefig('./Output/Precipitation vs Minutes Delayed - Subway 2014 - 2019')

plt.show()

# %% [markdown]
# <center><h2>Visualizing Delays</center></h2>

# %%
x = groupedbyday['Date']
y = groupedbyday['Min Delay']

fig, ax = plt.subplots(1, figsize = [15, 3.5])

ax.bar(
    x,
    y, 
    color = '#680000', 
    alpha = .8
)

ax.axhline(
    y = 1440, 
    color = 'red',
    lw = 2
)

ax.axhline(
    y = 0, 
    color = 'red', 
    lw = 2
)

ax.axvline(
    x = groupedbyday.iloc[0, 0], 
    color = 'red', 
    lw = 2
)

ax.axvline(
    x = groupedbyday.iloc[1945, 0], 
    color = 'red', 
    lw = 2
)

ax.set_ylabel('Minutes')
ax.set_xlabel('Days')
ax.set_title('TTC Subway Minutes Delayed by Day 2014 - 2019')

plt.minorticks_on()
plt.grid(b = True, which = 'minor', color = '#666666', linestyle = '-', alpha = 0.2)

plt.tight_layout()
plt.savefig('./Output/TTC_Subway_Mintues_Delayed_2014_2019.png')
plt.show()

# %% [markdown]
# Each x marker bar is representative of 1 day for a total of 1946 days. 1440 minutes are available in each day, so think of the space within the interior of the red box as time, with the dark blue bars of each delay as the amount of space in time the delays took.

# %%
fig, ax = plt.subplots(1, figsize = [12.5, 7])

ax.hist(
    groupedbyday['Min Delay'], 
    bins = 100, 
    color = '#680000'
)

ax.set_xlabel('Mintues')
ax.set_ylabel('Count')
ax.set_title('Histogram of Cumulative TTC Subway Minutes Delayed per Day 2014-2019')

plt.grid(
    b = True, 
    which = 'major', 
    color = '#666666', 
    linestyle = '-',
    alpha = 0.75
)

plt.minorticks_on()
plt.grid(
    b = True, 
    which = 'minor', 
    color = '#666666', 
    linestyle = '-', 
    alpha = 0.2
)

plt.tight_layout()
plt.savefig('./Output/Histogram of Cumulative TTC Subway Minutes Delayed per Day 2014 - 2019.png')

plt.show()

# %% [markdown]
# <center><h2>Incidents</h2></center>

# %%
descriptions = pd.DataFrame(subway['Description'].value_counts()).reset_index().rename(columns={'index': 'Description', 'Description': 'Count'}).reset_index()
#descriptions['Count Order'] = np.arange(1, len(descriptions['Description']))
descriptions.head(25)
# Out:
#     index                                        Description  Count
# 0       0                        Miscellaneous Speed Control  17720
# 1       1                              Operator Overspeeding  12884
# 2       2  Passenger Assistance Alarm Activated - No Trou...   7307
# 3       3  Injured or ill Customer (In Station) - Transpo...   6640
# 4       4                                Miscellaneous Other   5038
# 5       5                       Miscellaneous General Delays   4952
# 6       6                                  Disorderly Patron   4398
# 7       7  Injured or ill Customer (On Train) - Medical A...   3459
# 8       8   Injured or ill Customer (On Train) - Transported   2849
# 9       9                           Operator Violated Signal   2584
# 10     10                        Escalator/Elevator Incident   2578
# 11     11                   Door Problems - Faulty Equipment   2075
# 12     12                                    Passenger Other   1648
# 13     13  Injured or ill Customer (In Station) - Medical...   1511
# 14     14                                             Brakes   1474
# 15     15                          Speed Control Equipment     1367
# 16     16  Misc. Transportation Other - Employee Non-Char...   1325
# 17     17                     Door Problems - Debris Related   1105
# 18     18                         Station Stairway Incident    1070
# 19     19                         Operator Overshot Platform    937
# 20     20                          Assault / Patron Involved    930
# 21     21                              Signals - Train Stops    927
# 22     22                     Fire/Smoke Plan B - Source TTC    899
# 23     23                        Unauthorized at Track Level    891
# 24     24                  Transportation Department - Other    864

# %%
#value_counts.to_csv('subway_description_value_counts.csv')
#value_counts.head()

# %%
x
# Out:
# 0      2014-01-03
# 1      2014-01-04
# 2      2014-01-05
# 3      2014-01-06
# 4      2014-01-07
# 5      2014-01-08
# 6      2014-01-09
# 7      2014-01-10
# 8      2014-01-11
# 9      2014-01-12
# 10     2014-01-13
# 11     2014-01-14
# 12     2014-01-15
# 13     2014-01-16
# 14     2014-01-17
# 15     2014-01-18
# 16     2014-01-19
# 17     2014-01-20
# 18     2014-01-21
# 19     2014-01-22
# 20     2014-01-23
# 21     2014-01-24
# 22     2014-01-25
# 23     2014-01-26
# 24     2014-01-27
# 25     2014-01-28
# 26     2014-01-29
# 27     2014-01-30
# 28     2014-01-31
# 29     2014-02-01
#           ...
# 1916   2019-04-03
# 1917   2019-04-04
# 1918   2019-04-05
# 1919   2019-04-06
# 1920   2019-04-07
# 1921   2019-04-08
# 1922   2019-04-09
# 1923   2019-04-10
# 1924   2019-04-11
# 1925   2019-04-12
# 1926   2019-04-13
# 1927   2019-04-14
# 1928   2019-04-15
# 1929   2019-04-16
# 1930   2019-04-17
# 1931   2019-04-18
# 1932   2019-04-19
# 1933   2019-04-20
# 1934   2019-04-21
# 1935   2019-04-22
# 1936   2019-04-23
# 1937   2019-04-24
# 1938   2019-04-25
# 1939   2019-04-26
# 1940   2019-04-27
# 1941   2019-04-28
# 1942   2019-04-29
# 1943   2019-04-30
# 1944   2019-05-01
# 1945   2019-05-02
# Name: Date, Length: 1946, dtype: datetime64[ns]

# %% [markdown]
# <center><h2>Stations</center></h2>

# %%
stations = subway.groupby('Station').agg({
    'Min Delay': 'sum', 
}).rename(
    columns={
        'Min Delay': 'Sum', 
    })

stations = round(stations[stations['Sum'] > 0], 2)

# %%
stations = stations.dropna().reset_index()
len(stations)
# Out:
# 197

# %%
fig, ax = plt.subplots()

ax.barh(stations['Station'], stations['Sum'])
# Out:
# <BarContainer object of 197 artists>

# %%
stations.sort_values('Sum', ascending = False).head()
# Out:
#                    Station   Sum
# 71      KENNEDY BD STATION  8049
# 136  SHEPPARD WEST STATION  7631
# 43        EGLINTON STATION  6711
# 103        MCCOWAN STATION  6541
# 77     KENNEDY SRT STATION  5914

# %% [markdown]
# <center><h2>Days of the Week</center></h2>

# %%
subway.sample(5)
# Out:
#         Unnamed: 0       Date   Time        Day                Station   Code  \
# 57166        57166 2016-09-25  13:04     Friday   ST GEORGE BD STATION   MUSC
# 77132        77132 2017-10-07  11:30   Thursday          QUEEN STATION   MUIS
# 105262      105262 2019-02-14  06:37    Tuesday  YONGE UNIVERSITY LINE   TUST
# 39696        39696 2015-11-24  14:45     Sunday  YONGE UNIVERSITY LINE   MUGD
# 28378        28378 2015-05-15  19:26  Wednesday       LAWRENCE STATION  MUPAA
#
#         Min Delay  Min Gap Bound Line  ...  nDay  Max Temp (°C) Min Temp (°C)  \
# 57166           0        0     W   BD  ...    25           17.8           8.0
# 77132           0        0     N   YU  ...     7           25.3          16.8
# 105262          0        0   NaN   YU  ...    14            2.6          -4.5
# 39696           0        0   NaN   YU  ...    24            6.2          -1.2
# 28378           0        0     N   YU  ...    15           14.7           8.1
#
#         Mean Temp  Total Rain (mm)  Total Snow (cm)  Precipitation  \
# 57166        12.9              0.0              0.0            0.0
# 77132        21.1              2.9              0.0            2.9
# 105262       -1.0              0.4              0.0            0.4
# 39696         2.5              0.0              0.1            1.0
# 28378        11.4              0.2              0.0            0.2
#
#         Snow on Grnd (cm)  Spd of Max Gust (km/h)  holiday
# 57166                 0.0                      33     None
# 77132                 0.0                      49     None
# 105262                6.8                      36     None
# 39696                 0.4                      34     None
# 28378                 0.0                      35     None
#
# [5 rows x 24 columns]

# %%
weekdays = subway.groupby('Day').agg({
    'Min Delay': 'sum', 
    'Min Gap': 'sum',
    'Code': 'count'
}).rename(
    columns={'Min Delay': 'Sum of Minutes', 'Min Gap': 'Sum of Gap Minutes', 'Code': 'Incident Count'}).reset_index()
weekdays
# Out:
#          Day  Sum of Minutes  Sum of Gap Minutes  Incident Count
# 0     Friday           33593               49406           17099
# 1     Monday           32682               47833           16929
# 2   Saturday           27259               41291           12682
# 3     Sunday           22299               33808           10807
# 4   Thursday           32135               47519           17269
# 5    Tuesday           35236               50004           17154
# 6  Wednesday           33199               48047           17263

# %%
weekdays.head()
# Out:
#         Day  Sum of Minutes  Sum of Gap Minutes  Incident Count
# 0    Friday           33593               49406           17099
# 1    Monday           32682               47833           16929
# 2  Saturday           27259               41291           12682
# 3    Sunday           22299               33808           10807
# 4  Thursday           32135               47519           17269

# %%
bar1 = weekdays['Sum of Minutes']
bar2 = weekdays['Sum of Gap Minutes']

label = weekdays['Day']
barwidth = 1
names = weekdays['Day'].unique().tolist()
dayorder = [1, 5, 6, 4, 0, 2, 3]
names = [names[i] for i in dayorder]

bars = np.add(bar1, bar2).tolist()

fig, ax = plt.subplots(1, figsize = [12.5, 10])

p1 = ax.bar(label, bar1, color='#800000', edgecolor='white', width=barwidth)
p2 = ax.bar(label, bar2, bottom=bar1, color='#888888', edgecolor='white', width=barwidth)

ax.set_ylabel('Minutes')
ax.set_xlabel('Days of the Week')
ax.set_title('Subway Minutes Delayed per Day of the Week (2014 - Apr. 2019)')

plt.legend((p1[0], p2[0]), ('Minutes Delayed', 'Gap in Minutes'))

plt.xticks(label, names)

plt.minorticks_on()
plt.grid(
    b = True, 
    which = 'minor', 
    color = '#666666', 
    linestyle = '-', 
    alpha = 0.2
)

plt.tight_layout()

plt.savefig('./Output/Subway Minutes Delayed per Day of the Week.png')
plt.show()

# %%
subway.head()
# Out:
#    Unnamed: 0       Date   Time        Day                Station   Code  \
# 0           0 2014-01-03  00:21  Wednesday  VICTORIA PARK STATION  MUPR1
# 1           1 2014-01-03  02:06  Wednesday      HIGH PARK STATION   SUDP
# 2           2 2014-01-03  02:40  Wednesday       SHEPPARD STATION  MUNCA
# 3           3 2014-01-03  03:10  Wednesday      LANSDOWNE STATION   SUDP
# 4           4 2014-01-03  03:20  Wednesday          BLOOR STATION  MUSAN
#
#    Min Delay  Min Gap Bound Line  ...  nDay  Max Temp (°C) Min Temp (°C)  \
# 0         55       60     W   BD  ...     3           -7.6         -23.6
# 1          3        7     W   BD  ...     3           -7.6         -23.6
# 2          0        0   NaN   YU  ...     3           -7.6         -23.6
# 3          3        8     W   BD  ...     3           -7.6         -23.6
# 4          5       10     S   YU  ...     3           -7.6         -23.6
#
#    Mean Temp  Total Rain (mm)  Total Snow (cm)  Precipitation  \
# 0      -15.6              0.0              0.0            0.0
# 1      -15.6              0.0              0.0            0.0
# 2      -15.6              0.0              0.0            0.0
# 3      -15.6              0.0              0.0            0.0
# 4      -15.6              0.0              0.0            0.0
#
#    Snow on Grnd (cm)  Spd of Max Gust (km/h)  holiday
# 0                7.6                      34     None
# 1                7.6                      34     None
# 2                7.6                      34     None
# 3                7.6                      34     None
# 4                7.6                      34     None
#
# [5 rows x 24 columns]

# %% [markdown]
# <center><h2>Time of Day - Incident Counts</center></h2>

# %%
timeofday = subway.groupby(['Day', 'Time']).agg({'Min Delay': 'sum'}).reset_index()
timeofday['Time'] = pd.to_datetime(timeofday['Time'].str.strip(), format='%H:%M')
dailyincidents = subway.groupby(['Day', 'Time']).agg({'Min Delay': 'count'}).reset_index()
dailyincidents = dailyincidents.rename(columns={'Min Delay': 'Counts'})
timeofday['Counts'] = dailyincidents['Counts']
timeofday['Time'] = timeofday['Time'].dt.hour
timeofday = timeofday.groupby(['Day', 'Time']).agg({'Min Delay': 'sum', 'Counts': 'sum'}).reset_index().reset_index()
timeofday = timeofday.rename(columns={'index': 'Chronological'})

# %%
timeofday.head(10)
# Out:
#    Chronological     Day  Time  Min Delay  Counts
# 0              0  Friday     0       1552     503
# 1              1  Friday     1       1008     447
# 2              2  Friday     2         75     157
# 3              3  Friday     3         25      50
# 4              4  Friday     4          5      60
# 5              5  Friday     5       1054     497
# 6              6  Friday     6       1813    1138
# 7              7  Friday     7       1690     948
# 8              8  Friday     8       1703    1049
# 9              9  Friday     9       1467     857

# %%
fig, ax = plt.subplots(1, figsize = [12.5, 7])

ax.plot(
    timeofday['Chronological'], 
    timeofday['Counts'], 
    color = '#680000', 
    lw = 6
)

ax.set_ylabel('Incident Count')
ax.set_xlabel('Hours of the Week (168 Total)')

plt.grid(which = 'major', color = '#666666', linestyle = '-')
plt.minorticks_on()
plt.grid(which = 'minor', color = '#666666', linestyle = '-', alpha = 0.2)

plt.text(10, -175, 'Monday')
plt.text(36, -175, 'Tuesday')
plt.text(60, -175, 'Wednesday')
plt.text(85, -175, 'Thursday')
plt.text(112, -175, 'Friday')
plt.text(132, -175, 'Saturday')
plt.text(158, -175, 'Sunday')

plt.tight_layout()
plt.savefig('./Output/Line Graph of Weekly Subway Delay Incidents.png')

plt.show()

# %% [markdown]
# <center><h2>By Line</h2></center>

# %%
subway['Line'].value_counts()
# Out:
# BD                      51643
# YU                      48653
# SRT                      4010
# SHP                      3543
# YU/BD                    1004
# 999                         4
# 11 BAYVIEW                  2
# 16 MCCOWAN                  2
# 510 SPADINA                 2
# 555                         1
# 31 GREENWOOD                1
# 129 MCCOWAN NORTH           1
# 73 ROYAL YORK               1
# 126 CHRISTIE                1
# 29 DUFFERIN                 1
# YU/SHEP                     1
# 63 OSSINGTON                1
# 45 KIPLING                  1
# 37 ISLINGTON                1
# 9 BELLAMY                   1
# 504                         1
# 116 MORNINGSIDE             1
# 32 EGLINTON WEST            1
# 60                          1
# 504 KING                    1
# 60 STEELES WEST             1
# 36 FINCH WEST               1
# 704 RAD BUS                 1
# 500                         1
# 104 FAYWOOD                 1
# BLOOR DANFORTH LINES        1
# 341 KEELE                   1
# 85 SHEPPARD EAST            1
# BLOOR DANFORTH LINE         1
# 95 YORK MILLS               1
# Name: Line, dtype: int64

# %%
line = subway.groupby(['Date', 'Day', 'Line']).agg({'Min Delay': 'sum', 'Code': 'count'}).reset_index()
line = line[line['Min Delay'] > 0]
line = round(line.groupby(['Day', 'Line']).agg({'Min Delay': 'median', 'Code': 'mean'}), 2).reset_index()
line = line.rename(columns={'Min Delay': 'Median Minutes Delayed per Day', 'Code': 'Median # of Incidents per Day'})
line['Median Incident Length'] = round(line['Median Minutes Delayed per Day'] / line['Median # of Incidents per Day'], 2)
line['Combined'] = line['Day'] + ' ' + line['Line']

# %%
line.head()
# Out:
#       Day Line  Median Minutes Delayed per Day  Median # of Incidents per Day  \
# 0  Friday   BD                            44.0                          29.26
# 1  Friday  SHP                             5.5                           2.69
# 2  Friday  SRT                            10.0                           3.15
# 3  Friday   YU                            45.0                          27.32
# 4  Monday   BD                            41.0                          28.55
#
#    Median Incident Length    Combined
# 0                    1.50   Friday BD
# 1                    2.04  Friday SHP
# 2                    3.17  Friday SRT
# 3                    1.65   Friday YU
# 4                    1.44   Monday BD

# %%
monday = line[line['Day'] == 'Monday']
tuesday = line[line['Day'] == 'Tuesday']
wednesday = line[line['Day'] == 'Wednesday']
thursday = line[line['Day'] == 'Thursday']
friday = line[line['Day'] == 'Friday']
saturday = line[line['Day'] == 'Saturday']
sunday = line[line['Day'] == 'Sunday']

# %%
sunday
# Out:
#        Day Line  Median Minutes Delayed per Day  \
# 13  Sunday   BD                            23.0
# 14  Sunday  SHP                             6.0
# 15  Sunday  SRT                             8.0
# 16  Sunday   YU                            25.5
#
#     Median # of Incidents per Day  Median Incident Length    Combined
# 13                          17.45                    1.32   Sunday BD
# 14                           2.54                    2.36  Sunday SHP
# 15                           2.46                    3.25  Sunday SRT
# 16                          17.63                    1.45   Sunday YU

# %%
labels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
yu_medians = [44, 43, 41, 44, 45, 33, 25.5]
bd_medians = [41, 43, 43, 40, 44, 31, 23]
shp_medians = [6, 6, 6, 6, 5.5, 6, 6]
srt_medians = [11, 10, 10, 11, 10, 9, 8]

width = 0.172
r1 = np.arange(len(labels))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]
r4 = [x + width for x in r3]


fig, ax = plt.subplots(figsize = [12.5, 7])
bar1 = ax.bar(r1, yu_medians, width, color='#FFCC33', label='Yonge/University')
bar2 = ax.bar(r2, bd_medians, width, color='#009966', label='Bloor/Danforth')
bar3 = ax.bar(r3, shp_medians, width, color='#993366', label='Sheppard')
bar4 = ax.bar(r4, srt_medians, width, color='#0099cc', label='Scarborough RT')


ax.set_ylabel('Minutes')
ax.set_title('Median Subway Delays in Minutes by Day')
#ax.set_xticks(x + 0.25)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()

# %%
sunday
# Out:
#        Day Line  Median Minutes Delayed per Day  \
# 13  Sunday   BD                            23.0
# 14  Sunday  SHP                             6.0
# 15  Sunday  SRT                             8.0
# 16  Sunday   YU                            25.5
#
#     Median # of Incidents per Day  Median Incident Length    Combined
# 13                          17.45                    1.32   Sunday BD
# 14                           2.54                    2.36  Sunday SHP
# 15                           2.46                    3.25  Sunday SRT
# 16                          17.63                    1.45   Sunday YU

# %%
labels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
yu_incidents = [27.43, 27.66, 27.11, 27.58, 27.32, 20.45, 17.63]
bd_incidents = [28.55, 29.34, 30.09, 29.51, 29.26, 21.23, 17.45]
shp_incidents = [3.02, 2.77, 2.67, 2.97, 2.69, 2.77, 2.54]
srt_incidents = [3.05, 2.96, 3.3, 3.03, 3.15, 2.63, 2.46]

width = 0.172
r1 = np.arange(len(labels))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]
r4 = [x + width for x in r3]


fig, ax = plt.subplots(figsize = [12.5, 7])
bar1 = ax.bar(r1, yu_incidents, width, color='#FFCC33', label='Yonge/University')
bar2 = ax.bar(r2, bd_incidents, width, color='#009966', label='Bloor/Danforth')
bar3 = ax.bar(r3, shp_incidents, width, color='#993366', label='Sheppard')
bar4 = ax.bar(r4, srt_incidents, width, color='#0099cc', label='Scarborough RT')


ax.set_ylabel('Minutes')
ax.set_title('Median Subway Delay Incidents by Day')
#ax.set_xticks(x + .25)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()
